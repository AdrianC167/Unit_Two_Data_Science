# %% [markdown]
# # File Operations
# In this excercise you will begin working on using the `open` function within python to manipulate files and create reports on those files.
#
# **YOU ARE TO INCLUDE COMMENTS ALONG SIDE YOUR CODE**

# %% [markdown]
# 1. Open the file "states.txt" that you downloaded, what does this file contain?
# ```
# This text file contains a list of 1000 states.
# ```

# %% [markdown]
# *Use the code block below to open the same file, using a `for` loop print each line to the console.*

# %%
#statelist variable is created and equal to the opened state.txt file
stateslist = open ("states.txt")
#uses with function to clean up after code usage and renames as statelist
with open("states.txt") as statelist:
    #makes statelist equal to state and readlines reads it as a list of strings
    state = statelist.readlines()
#for loop prints out every list item individually in its own line
for x in state:
    #prints
    print(x)
# Out:
# WA
#
# MO
#
# KS
#
# SC
#
# GA
#
# FL
#
# MN
#
# NC
#
# HI
#
# CT
#
# TX
#
# MA
#
# OK
#
# IL
#
# HI
#
# CA
#
# TX
#
# WA
#
# OH
#
# PA
#
# MO
#
# IL
#
# CA
#
# IL
#
# CA
#
# DC
#
# FL
#
# NC
#
# NY
#
# VA
#
# TX
#
# CA
#
# DC
#
# TX
#
# OH
#
# WA
#
# FL
#
# MN
#
# DC
#
# FL
#
# CA
#
# FL
#
# TX
#
# CT
#
# NC
#
# MO
#
# TX
#
# MA
#
# TX
#
# WA
#
# IN
#
# IN
#
# MO
#
# AL
#
# OK
#
# GA
#
# NY
#
# IN
#
# OK
#
# IN
#
# CA
#
# GA
#
# CA
#
# CA
#
# IN
#
# NY
#
# MS
#
# CA
#
# NV
#
# ID
#
# MN
#
# VA
#
# WY
#
# WV
#
# MN
#
# MO
#
# TX
#
# MA
#
# IN
#
# IA
#
# WA
#
# MN
#
# CA
#
# NE
#
# IL
#
# IL
#
# PA
#
# GA
#
# TX
#
# OH
#
# DE
#
# TX
#
# NM
#
# TX
#
# MA
#
# LA
#
# GA
#
# TN
#
# CA
#
# DC
#
# FL
#
# CO
#
# MI
#
# MD
#
# FL
#
# FL
#
# NC
#
# OH
#
# IA
#
# NE
#
# TX
#
# IN
#
# TX
#
# CA
#
# TX
#
# IL
#
# CA
#
# VA
#
# TX
#
# CA
#
# NY
#
# IN
#
# NY
#
# OH
#
# NY
#
# TN
#
# DC
#
# CA
#
# MN
#
# VA
#
# UT
#
# NH
#
# TX
#
# CA
#
# PA
#
# CO
#
# TX
#
# FL
#
# CA
#
# PA
#
# OH
#
# MD
#
# CT
# ...

# %% [markdown]
# 2. What type of chart would be best to represent this data? Explain why
# ```
# The best chart that would represent this would be a bar graph because there are duplicate states and you can list the states on the x axis and how many duplicates on the y axis.
# ```
# 3. How would we need to transform the data we have, to be displayed in this chart?
# ```
# The state names can be displayed on the x axis and the number of duplicates can be the y axis.
# ```

# %% [markdown]
# Using your knowledge of Python and Matplotlib write your code to transform and graph the data below.
#
# After your code create a new Markdown block to describe your analysis

# %%
import matplotlib.pyplot as plt


AL = 0
AK = 0
AZ = 0
AR = 0
CA = 0
CO = 0
CT = 0
DE = 0
FL = 0
GA = 0
HI = 0
ID = 0
IL = 0
IN = 0
IA = 0
KS = 0
KY = 0
LA = 0
ME = 0
MD = 0
MA = 0
MI = 0
MN = 0
MS = 0
MO = 0
MT = 0 
NE = 0
NV = 0
NH = 0
NJ = 0
NM = 0
NY = 0
NC = 0
ND = 0
OH = 0
OK = 0
OR = 0
PA = 0
RI = 0
SC = 0
SD = 0
TN = 0
TX = 0
UT = 0
VT = 0
VA = 0
WA = 0
WV = 0
WI = 0
WY = 0
for x in state:

    if x == 'AL\n':
        AL +=1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1   
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1
    elif x == 'AK\n':
        AK += 1  
    

plt.bar(['wa', 'ny'],[y, ny_count])
# Out:
# <BarContainer object of 2 artists>
